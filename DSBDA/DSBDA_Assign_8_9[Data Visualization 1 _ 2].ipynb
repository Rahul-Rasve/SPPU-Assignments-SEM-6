# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Data Visualization

# %%
sns.displot(df['Pclass'])

# %%
sns.displot(df['Age'], bins=40)

# %%
sns.displot(df['Age'], bins=20, kde=False, rug=True)

# %%
sns.jointplot(x=df['Age'], y=df['Fare'], kind='scatter')

# %%
sns.jointplot(x=df['Age'], y=df['Fare'], kind='hex')

# %%
sns.pairplot(df) #all possible plots

# %%
sns.barplot(x=df['Sex'], y=df['Fare'])
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
sns.countplot(x=df['Sex'], data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.histplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
#piechart
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f%%') #2 decimal places with '%' sign
# Out:
# <Axes: ylabel='Sex'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%d') #integer values without '%' sign
# Out:
# <Axes: ylabel='Survived'>

# %%
#barplot showing relation
sns.barplot(x=df['Survived'], y=df['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x=df['Sex'], y=df['Age'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['Sex'], y=df['Age'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#cross table
cross = pd.crosstab(df['Sex'], df['Survived'])
cross
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
sns.heatmap(cross)
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
cross1 = pd.crosstab(df['Age'], df['Survived'])
sns.heatmap(cross1)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
#clustermap
sns.clustermap(cross)

# %%
sns.clustermap(cross1)
